# %% [markdown]
# # Implementing decision tree algorithm and test the algorithm

# %%
# importing librabries
import numpy  as  np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import confusion_matrix
from sklearn. preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split 
from sklearn import metrics

# %% [markdown]
# Red Wine Quality Dataset : The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult the reference [Cortez et al., 2009]. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# These datasets can be viewed as classification or regression tasks. The classes are ordered and not balanced (e.g. there are much more normal wines than excellent or poor ones).

# %%
#reading the  dataset
vishnu =  pd.read_csv("C:/Users/tmvis/Downloads/archive (1)/winequality-red.csv")
X = vishnu.iloc[:, 8:11].values 
y = vishnu.iloc[:, 11].values

# %% [markdown]
# FIRST FIVE ROWS OF THE DATASET

# %%
vishnu.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Encoding Categorical data

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder 
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1]) 
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2]) 
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([("pH", OneHotEncoder(), [1])], remainder = 'passthrough')
X = ct.fit_transform(X)
X = X[:, 1:]

# %% [markdown]
# Splitting the dataset into the Training set and Test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15,
random_state = 0, stratify = y)

# %% [markdown]
# Feature Scaling

# %%
sc = StandardScaler(with_mean=False)
X_train = sc.fit_transform(X_train) 
X_test = sc.transform(X_test)

# %% [markdown]
# Defining the Machine Learning Models

# %%
model2 = DecisionTreeClassifier(max_depth = 2)

# %% [markdown]
# Training the machine learning models

# %%
model2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# Making the Prediction

# %%
y_pred2 = model2.predict(X_test)

# %% [markdown]
# Confusion Matrix

# %%
cm_DecisionTree = confusion_matrix(y_test, y_pred2)
cm_DecisionTree
# Out:
# array([[ 0,  0,  0,  1,  0,  0],
#        [ 0,  0,  5,  3,  0,  0],
#        [ 0,  0, 79, 23,  0,  0],
#        [ 0,  0, 50, 46,  0,  0],
#        [ 0,  0,  3, 27,  0,  0],
#        [ 0,  0,  0,  3,  0,  0]], dtype=int64)

# %%
print('Accuracy Score on test data: ',metrics.accuracy_score(y_test, y_pred2))
# Out:
# Accuracy Score on test data:  0.5208333333333334

# %% [markdown]
# Assigning TP,TN,FP,FN

# %%
TP = cm_DecisionTree[3,3]
TN = cm_DecisionTree[2,2]
FP = cm_DecisionTree[2,3]
FN = cm_DecisionTree[3,2]

# %% [markdown]
# Precision rate

# %%
precision = TP / (TP + FP)
np.seterr(divide='ignore', invalid='ignore')
print(precision)
# Out:
# 0.6666666666666666

# %% [markdown]
# Recall Rate

# %%
Recall = TP/(TP/FN)
Recall
# Out:
# 50.0

# %% [markdown]
# Accuracy

# %%
Accuracy = ((TP+TN))/ float(TP+TN+FP+FN)
Accuracy
# Out:
# 0.6313131313131313

# %% [markdown]
# Error Rate

# %%
Error = (FP+FN)/ float(TP+TN+FP+FN)
Error
# Out:
# 0.3686868686868687
